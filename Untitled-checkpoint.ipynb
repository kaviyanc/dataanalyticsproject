# %% [markdown]
# # library installation

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # importing library

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # scraping website

# %%
url="https://www.digit.in/top-products/best-drones-with-camera-3764.html"

# %% [markdown]
# # website response

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# # parsing

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# ...

# %%
drone=soup.select("#toptenIdevent1 , h3")

# %%
drone
# Out:
# [<div class="TopNumbeHeading active sticky-footer" data-cat="Top_Ten_En_Scroll" data-eventaction="NonAMPScroll" data-index="1" data-lang="en" data-proname="1_Tathastu Enterprise Drone" data-title="Tathastu Enterprise Drone" id="toptenIdevent1">
#  <span>1.</span>
#  <a href="https://www.digit.in/drones/tathastu-enterprise-drone-price-239537.html">
#  <h3>TATHASTU ENTERPRISE DRONE</h3>
#  </a>
#  </div>,
#  <h3>TATHASTU ENTERPRISE DRONE</h3>,
#  <h3>R FOLDABLE GPS DRONE</h3>,
#  <h3>A ASCETIC FOLDABLE DRONE</h3>,
#  <h3>A QUADCOPTER DRONE</h3>,
#  <h3>CHAWLA AGENCY DRONE</h3>,
#  <h3>OCTRA DRONE</h3>,
#  <h3>AMITASHA CAMERA DRONE</h3>,
#  <h3>LDS DRONE</h3>,
#  <h3>LIVOX DRONE</h3>,
#  <h3>AAAA DRONE</h3>]

# %%
drone_list=[]

# %%
for item in drone:
    drone_list.append(item.text)
    drone_list

# %%
drone_list
# Out:
# ['\n1.\n\nTATHASTU ENTERPRISE DRONE\n\n',
#  'TATHASTU ENTERPRISE DRONE',
#  'R FOLDABLE GPS DRONE',
#  'A ASCETIC FOLDABLE DRONE',
#  'A QUADCOPTER DRONE',
#  'CHAWLA AGENCY DRONE',
#  'OCTRA DRONE',
#  'AMITASHA CAMERA DRONE',
#  'LDS DRONE',
#  'LIVOX DRONE',
#  'AAAA DRONE']

# %%
pixel=soup.select("li:nth-child(2) .value")

# %%
camera_pixel=[]

# %%
for item in pixel:
    camera_pixel.append(item.text)
    camera_pixel

# %%
camera_pixel
# Out:
# ['2MP', '480p', '1080p HD Camera', '7MP , 2 MP', 'NA', '780p Camera']

# %%
amount=soup.select("strong")

# %%
amount
# Out:
# [<strong>₹ 4,099</strong>,
#  <strong>₹ 4,799</strong>,
#  <strong>₹ 5,299</strong>,
#  <strong>₹ 6,999</strong>,
#  <strong>₹ 3,999</strong>,
#  <strong>₹ 5,999</strong>,
#  <strong>About Me: </strong>]

# %%
meter=soup.select('.full_width~ li+ li .value')

# %%
meter
# Out:
# [<div class="value">40 meters</div>,
#  <div class="value">Upto 50 mtrs</div>,
#  <div class="value">60 meters</div>,
#  <div class="value">40 - 50 meters</div>,
#  <div class="value">25-30 mtrs</div>,
#  <div class="value">Up to 5 Ft.</div>]

# %%
flying_meter=[]

# %%
for item in meter:
    flying_meter.append(item.text)
    flying_meter

# %%
flying_meter
# Out:
# ['40 meters',
#  'Upto 50 mtrs',
#  '60 meters',
#  '40 - 50 meters',
#  '25-30 mtrs',
#  'Up to 5 Ft.']

# %% [markdown]
# # drones and frames

# %%
import pandas as pd

# %%
digit=pd.DataFrame(drone_list,columns=["drone_list"])

# %%
digit
# Out:
#                                drone_list
# 0   \n1.\n\nTATHASTU ENTERPRISE DRONE\n\n
# 1               TATHASTU ENTERPRISE DRONE
# 2                    R FOLDABLE GPS DRONE
# 3                A ASCETIC FOLDABLE DRONE
# 4                      A QUADCOPTER DRONE
# 5                     CHAWLA AGENCY DRONE
# 6                             OCTRA DRONE
# 7                   AMITASHA CAMERA DRONE
# 8                               LDS DRONE
# 9                             LIVOX DRONE
# 10                             AAAA DRONE

# %% [markdown]
# # save

# %%
digit.to_csv('digit.csv')
